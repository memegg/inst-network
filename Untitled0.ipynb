# %% [markdown]
# <a href="https://colab.research.google.com/github/memegg/inst-network/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# تحميل ملف البيانات من جهاز الكمبيوتر الخاص بك
uploaded = files.upload()
# Out:
#      <input type="file" id="files-547e8fe2-36db-4b89-8b81-bcbd7f9c9278" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-547e8fe2-36db-4b89-8b81-bcbd7f9c9278">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3933cbe0-2591-49fd-a2e5-aed5d4a443dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3933cbe0-2591-49fd-a2e5-aed5d4a443dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install optuna

# %%
# %pip install numpy pandas seaborn matplotlib optuna sklearn xgboost catboost lightgbm > /dev/null 2>&1

# %%
# !pip install catboost

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype
import warnings
import optuna
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree  import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import BernoulliNB
from lightgbm import LGBMClassifier
from sklearn.feature_selection import RFE
import itertools
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from tabulate import tabulate
import os
warnings.filterwarnings('ignore')
optuna.logging.set_verbosity(optuna.logging.WARNING)
for dirname, _, filenames in os.walk('/kaggle/input'):
  for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train=pd.read_csv('Train_data.csv')
test=pd.read_csv('Test_data.csv')
train
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     25192 non-null  int64
#  1   protocol_type                25192 non-null  object
#  2   service                      25192 non-null  object
#  3   flag                         25192 non-null  object
#  4   src_bytes                    25192 non-null  int64
#  5   dst_bytes                    25192 non-null  int64
#  6   land                         25192 non-null  int64
#  7   wrong_fragment               25192 non-null  int64
#  8   urgent                       25192 non-null  int64
#  9   hot                          25192 non-null  int64
#  10  num_failed_logins            25192 non-null  int64
#  11  logged_in                    25192 non-null  int64
#  12  num_compromised              25192 non-null  int64
# ...

# %%
train.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
train.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# ...

# %%
train.describe(include='object')
# Out:
#        protocol_type service   flag   class
# count          25192   25192  25192   25192
# unique             3      66     11       2
# top              tcp    http     SF  normal
# freq           20526    8003  14973   13449

# %%
total = train.shape[0]
missing_columns = [col for col in train.columns if train[col].isnull().sum() > 0]
for col in missing_columns:
    null_count = train[col].isnull().sum()
    per = (null_count/total) * 100
    print(f"{col}: {null_count} ({round(per, 3)}%)")

# %%
print(f"Number of duplicate rows: {train.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
# for col in df:
#     if col != 'class' and is_numeric_dtype(df[col]):
#         fig, ax = plt.subplots(2, 1, figsize=(12, 8))
#         g1 = sns.boxplot(x = df[col], ax=ax[0])
#         g2 = sns.scatterplot(data=df, x=df[col],y=df['class'], ax=ax[1])
#         plt.show()

# %%
plt.figure(figsize=(40,30))
sns.heatmap(train.corr(), annot=True)

# import plotly.express as px
# fig = px.imshow(df.corr(), text_auto=True, aspect="auto")
# fig.show()
# Out:
# <Axes: >

# %%
sns.countplot(x=train['class'])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
def le(df):
    for col in df.columns:
        if df[col].dtype == 'object':
                label_encoder = LabelEncoder()
                df[col] = label_encoder.fit_transform(df[col])

le(train)
le(test)

# %%
train.drop(['num_outbound_cmds'], axis=1, inplace=True)
test.drop(['num_outbound_cmds'], axis=1, inplace=True)
train.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# ...

# %%
X_train = train.drop(['class'], axis=1)
Y_train = train['class']

# %%
rfc = RandomForestClassifier()

rfe = RFE(rfc, n_features_to_select=10)
rfe = rfe.fit(X_train, Y_train)

feature_map = [(i, v) for i, v in itertools.zip_longest(rfe.get_support(), X_train.columns)]
selected_features = [v for i, v in feature_map if i==True]

selected_features
# Out:
# ['protocol_type',
#  'service',
#  'flag',
#  'src_bytes',
#  'dst_bytes',
#  'count',
#  'same_srv_rate',
#  'diff_srv_rate',
#  'dst_host_srv_count',
#  'dst_host_same_srv_rate']

# %%
X_train = X_train[selected_features]

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
test = scale.fit_transform(test)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, train_size=0.70, random_state=2)

# %% [markdown]
# **bold text**

# %%
def objective(trial):
    n_neighbors = trial.suggest_int('KNN_n_neighbors', 2, 16, log=False)
    classifier_obj = KNeighborsClassifier(n_neighbors=n_neighbors)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_KNN = optuna.create_study(direction='maximize')
study_KNN.optimize(objective, n_trials=1)
print(study_KNN.best_trial)
# Out:
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.9813442709711564], datetime_start=datetime.datetime(2024, 4, 1, 0, 57, 27, 910677), datetime_complete=datetime.datetime(2024, 4, 1, 0, 57, 28, 986065), params={'KNN_n_neighbors': 10}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'KNN_n_neighbors': IntDistribution(high=16, log=False, low=2, step=1)}, trial_id=0, value=None)

# %%
KNN_model = KNeighborsClassifier(n_neighbors=study_KNN.best_trial.params['KNN_n_neighbors'])
KNN_model.fit(x_train, y_train)

KNN_train, KNN_test = KNN_model.score(x_train, y_train), KNN_model.score(x_test, y_test)

print(f"Train Score: {KNN_train}")
print(f"Test Score: {KNN_test}")
# Out:
# Train Score: 0.9831008279460134
# Test Score: 0.9813442709711564

# %%
lg_model = LogisticRegression(random_state = 42)
lg_model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lg_train, lg_test = lg_model.score(x_train , y_train), lg_model.score(x_test , y_test)

print(f"Training Score: {lg_train}")
print(f"Test Score: {lg_test}")
# Out:
# Training Score: 0.9287739593966202
# Test Score: 0.9231278115903678

# %%
from sklearn.ensemble import RandomForestClassifier

def objective(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32, log=False)
    rf_max_features = trial.suggest_int('rf_max_features', 2, 10, log=False)
    classifier_obj = RandomForestClassifier(max_depth=rf_max_depth, max_features=rf_max_features)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective, n_trials=30)
print(study_dt.best_trial)
# Out:
# FrozenTrial(number=18, state=TrialState.COMPLETE, values=[0.9969568668960043], datetime_start=datetime.datetime(2024, 4, 1, 0, 58, 7, 392444), datetime_complete=datetime.datetime(2024, 4, 1, 0, 58, 8, 673028), params={'rf_max_depth': 15, 'rf_max_features': 3}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'rf_max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'rf_max_features': IntDistribution(high=10, log=False, low=2, step=1)}, trial_id=18, value=None)

# %%
# استيراد الطراز
from sklearn.tree import DecisionTreeClassifier

# التحقق من وجود المعلمات "dt_max_depth" و "dt_max_features"
if 'dt_max_depth' in study_dt.best_trial.params:
    dt_max_depth = study_dt.best_trial.params['dt_max_depth']
else:
    dt_max_depth = None

# إنشاء نموذج DecisionTreeClassifier باستخدام المعلمات
dt = DecisionTreeClassifier(max_depth=dt_max_depth)

# تدريب النموذج
dt.fit(x_train, y_train)

# حساب النتائج
dt_train_score = dt.score(x_train, y_train)
dt_test_score = dt.score(x_test, y_test)

print(f"Training Score: {dt_train_score}")
print(f"Test Score: {dt_test_score}")
# Out:
# Training Score: 1.0
# Test Score: 0.9943106641968775

# %%
fig = plt.figure(figsize = (30,12))
tree.plot_tree(dt, filled=True);
plt.show()

# %%
from matplotlib import pyplot as plt
def f_importance(coef, names, top=-1):
    imp = coef
    imp, names = zip(*sorted(list(zip(imp, names))))

    # Show all features
    if top == -1:
        top = len(names)

    plt.barh(range(top), imp[::-1][0:top], align='center')
    plt.yticks(range(top), names[::-1][0:top])
    plt.title('feature importance for dt')
    plt.show()

# whatever your features are called
features_names = selected_features

# Specify your top n features you want to visualize.
# You can also discard the abs() function
# if you are interested in negative contribution of features
f_importance(abs(dt.feature_importances_), features_names, top=7)

# %%
def objective(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32, log=False)
    rf_max_features = trial.suggest_int('rf_max_features', 2, 10, log=False)
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 3, 20, log=False)
    classifier_obj = RandomForestClassifier(max_features = rf_max_features, max_depth = rf_max_depth, n_estimators = rf_n_estimators)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective, n_trials=30)
print(study_rf.best_trial)
# Out:
# FrozenTrial(number=29, state=TrialState.COMPLETE, values=[0.9964276263561789], datetime_start=datetime.datetime(2024, 4, 1, 0, 58, 40, 740279), datetime_complete=datetime.datetime(2024, 4, 1, 0, 58, 41, 25514), params={'rf_max_depth': 30, 'rf_max_features': 3, 'rf_n_estimators': 20}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'rf_max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'rf_max_features': IntDistribution(high=10, log=False, low=2, step=1), 'rf_n_estimators': IntDistribution(high=20, log=False, low=3, step=1)}, trial_id=29, value=None)

# %%
rf = RandomForestClassifier(max_features = study_rf.best_trial.params['rf_max_features'], max_depth = study_rf.best_trial.params['rf_max_depth'], n_estimators = study_rf.best_trial.params['rf_n_estimators'])
rf.fit(x_train, y_train)

rf_train, rf_test = rf.score(x_train, y_train), rf.score(x_test, y_test)

print(f"Train Score: {rf_train}")
print(f"Test Score: {rf_test}")
# Out:
# Train Score: 0.9997164568447318
# Test Score: 0.9961630060862662

# %%
from matplotlib import pyplot as plt

def f_importance(coef, names, top=-1):
    imp = coef
    imp, names = zip(*sorted(list(zip(imp, names))))

    # Show all features
    if top == -1:
        top = len(names)
    plt.barh(range(top), imp[::-1][0:top], align='center')
    plt.yticks(range(top), names[::-1][0:top])
    plt.title('feature importance for dt')
    plt.show()

# whatever your features are called
features_names = selected_features

# Specify your top n features you want to visualize.
# You can also discard the abs() function
# if you are interested in negative contribution of features
f_importance(abs(rf.feature_importances_), features_names, top=7)

# %%
lgb_model = LGBMClassifier(random_state=42)
lgb_model.fit(x_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 9389, number of negative: 8245
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000728 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1301
# [LightGBM] [Info] Number of data points in the train set: 17634, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.532437 -> initscore=0.129932
# [LightGBM] [Info] Start training from score 0.129932
# LGBMClassifier(random_state=42)

# %%
lgb_train, lgb_test = lgb_model.score(x_train , y_train), lgb_model.score(x_test , y_test)

print(f"Training Score: {lgb_train}")
print(f"Test Score: {lgb_test}")
# Out:
# Training Score: 1.0
# Test Score: 0.9965599364911352

# %%
ab_model = AdaBoostClassifier(random_state=42)

# %%
ab_model.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
ab_train, ab_test = ab_model.score(x_train , y_train), ab_model.score(x_test , y_test)

print(f"Training Score: {ab_train}")
print(f"Test Score: {ab_test}")
# Out:
# Training Score: 0.9800385618691165
# Test Score: 0.9790949986768986

# %%
cb_model = CatBoostClassifier(verbose=0)
cb_model.fit(x_train, y_train)

# %%
cb_train, cb_test = cb_model.score(x_train , y_train), cb_model.score(x_test , y_test)

print(f"Training Score: {cb_train}")
print(f"Test Score: {cb_test}")
# Out:
# Training Score: 0.9985822842236588
# Test Score: 0.9956337655464409

# %%
BNB_model = BernoulliNB()
BNB_model.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
BNB_train, BNB_test = BNB_model.score(x_train , y_train), BNB_model.score(x_test , y_test)

print(f"Training Score: {BNB_train}")
print(f"Test Score: {BNB_test}")
# Out:
# Training Score: 0.8975842123171147
# Test Score: 0.8970627150039693

# %%
v_clf = VotingClassifier(estimators=[('KNeighborsClassifier', KNN_model), ("RandomForestClassifier", rf), ("DecisionTree", dt), ("LightGB", lgb_model), ("AdaBoost", ab_model), ("Catboost", cb_model)], voting = "hard")

# %%
v_clf.fit(x_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 9389, number of negative: 8245
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1301
# [LightGBM] [Info] Number of data points in the train set: 17634, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.532437 -> initscore=0.129932
# [LightGBM] [Info] Start training from score 0.129932
# VotingClassifier(estimators=[('KNeighborsClassifier',
#                               KNeighborsClassifier(n_neighbors=10)),
#                              ('RandomForestClassifier',
#                               RandomForestClassifier(max_depth=30,
#                                                      max_features=3,
#                                                      n_estimators=20)),
# ...

# %%
voting_train, voting_test = v_clf.score(x_train , y_train), v_clf.score(x_test , y_test)

print(f"Training Score: {voting_train}")
print(f"Test Score: {voting_test}")
# Out:
# Training Score: 0.9997731654757854
# Test Score: 0.9964276263561789

# %%
def objective(trial):
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'linearSVC'])
    c = trial.suggest_float('c', 0.02, 1.0, step=0.02)
    if kernel in ['linear', 'rbf']:
        classifier_obj = SVC(kernel=kernel, C=c).fit(x_train, y_train)
    elif kernel == 'linearSVC':
        classifier_obj = LinearSVC(C=c).fit(x_train, y_train)
    elif kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 10)
        classifier_obj = SVC(kernel=kernel, C=c, degree=degree).fit(x_train, y_train)

    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_svm = optuna.create_study(direction='maximize')
study_svm.optimize(objective, n_trials=30)
print(study_svm.best_trial)
# Out:
# FrozenTrial(number=20, state=TrialState.COMPLETE, values=[0.9708917703096057], datetime_start=datetime.datetime(2024, 4, 1, 1, 0, 23, 365543), datetime_complete=datetime.datetime(2024, 4, 1, 1, 0, 26, 53869), params={'kernel': 'rbf', 'c': 1.0}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'kernel': CategoricalDistribution(choices=('linear', 'rbf', 'poly', 'linearSVC')), 'c': FloatDistribution(high=1.0, log=False, low=0.02, step=0.02)}, trial_id=20, value=None)

# %%
if study_svm.best_trial.params['kernel'] in ['linear', 'rbf']:
    SVM_model = SVC(kernel=study_svm.best_trial.params['kernel'], C=study_svm.best_trial.params['c'])
elif kernel == 'linearSVC':
    SVM_model = LinearSVC(C=study_svm.best_trial.params['c'])
elif kernel == 'poly':
    SVM_model = SVC(kernel=study_svm.best_trial.params['kernel'], C=study_svm.best_trial.params['c'], degree=study_svm.best_trial.params['degree'])

SVM_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
SVM_train, SVM_test = SVM_model.score(x_train , y_train), SVM_model.score(x_test , y_test)

print(f"Training Score: {SVM_train}")
print(f"Test Score: {SVM_test}")
# Out:
# Training Score: 0.9683565838720654
# Test Score: 0.9708917703096057

# %%
# Train Decision Tree Classifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)

# Evaluate Decision Tree Classifier
dt_train = dt.score(x_train, y_train)
dt_test = dt.score(x_test, y_test)

# %%
data = [["KNN", KNN_train, KNN_test],
        ["Logistic Regression", lg_train, lg_test],
        ["Decision Tree", dt_train, dt_test],
        ["Random Forest", rf_train, rf_test],
        ["Adaboost", ab_train, ab_test],
        ["light GBM", lgb_train, lgb_test],
        ["CatBoost", cb_train, cb_test],
        ["Naive Baye Model", BNB_train, BNB_test],
        ["Voting", voting_train, voting_test],
        ["SVM", SVM_train, SVM_test]]

col_names = ["Model", "Train Score", "Test Score"]
print(tabulate(data, headers=col_names, tablefmt="fancy_grid"))
# Out:
# ╒═════════════════════╤═══════════════╤══════════════╕
# │ Model               │   Train Score │   Test Score │
# ╞═════════════════════╪═══════════════╪══════════════╡
# │ KNN                 │      0.983101 │     0.981344 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Logistic Regression │      0.928774 │     0.923128 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Decision Tree       │      1        │     0.994443 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Random Forest       │      0.999716 │     0.996163 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ Adaboost            │      0.980039 │     0.979095 │
# ├─────────────────────┼───────────────┼──────────────┤
# │ light GBM           │      1        │     0.99656  │
# ├─────────────────────┼───────────────┼──────────────┤
# │ CatBoost            │      0.998582 │     0.995634 │
# ├─────────────────────┼───────────────┼──────────────┤
# ...

# %%
import matplotlib.pyplot as plt

# قائمة بأسماء النماذج
models = ["KNN", "Logistic Regression", "Decision Tree", "Random Forest", "Adaboost", "Light GBM", "CatBoost", "Naive Bayes", "Voting", "SVM"]

# قائمة بنتائج التدريب والاختبار
train_scores = [KNN_train, lg_train, dt_train, rf_train, ab_train, lgb_train, cb_train, BNB_train, voting_train, SVM_train]
test_scores = [KNN_test, lg_test, dt_test, rf_test, ab_test, lgb_test, cb_test, BNB_test, voting_test, SVM_test]

# رسم الرسم البياني
plt.figure(figsize=(10, 6))
plt.plot(models, train_scores, marker='o', label='Train Accuracy')
plt.plot(models, test_scores, marker='x', label='Test Accuracy')
plt.title('Model Train and Test Accuracy')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

# حساب التنبؤات لكل نموذج
y_pred_KNN = KNN_model.predict(x_test)
y_pred_logistic = lg_model.predict(x_test)
y_pred_dt = dt.predict(x_test)  # استبدل بالمتغير الصحيح لنموذج الشجرة القرارية

y_pred_rf = rf.predict(x_test)  # استبدل بالمتغير الصحيح لنموذج الغابات العشوائية


# حساب مصفوفة الالتباس لكل نموذج
cm_KNN = confusion_matrix(y_test, y_pred_KNN)
cm_logistic = confusion_matrix(y_test, y_pred_logistic)
cm_dt = confusion_matrix(y_test, y_pred_dt)
cm_rf = confusion_matrix(y_test, y_pred_rf)

# %%
# عرض مصفوفة الالتباس لكل نموذج
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
sns.heatmap(cm_KNN, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix - KNN')

plt.subplot(2, 2, 2)
sns.heatmap(cm_logistic, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix - Logistic Regression')

plt.subplot(2, 2, 3)
sns.heatmap(cm_dt, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix - Decision Tree')

plt.subplot(2, 2, 4)
sns.heatmap(cm_rf, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix - Random Forest')

plt.tight_layout()
plt.show()

# حساب مقاييس الأداء لكل نموذج
precision_KNN = precision_score(y_test, y_pred_KNN)
precision_logistic = precision_score(y_test, y_pred_logistic)
precision_dt = precision_score(y_test, y_pred_dt)
precision_rf = precision_score(y_test, y_pred_rf)

recall_KNN = recall_score(y_test, y_pred_KNN)
recall_logistic = recall_score(y_test, y_pred_logistic)
recall_dt = recall_score(y_test, y_pred_dt)
recall_rf = recall_score(y_test, y_pred_rf)

f1_KNN = f1_score(y_test, y_pred_KNN)
f1_logistic = f1_score(y_test, y_pred_logistic)
f1_dt = f1_score(y_test, y_pred_dt)
f1_rf = f1_score(y_test, y_pred_rf)

# عرض مقاييس الأداء لكل نموذج
models = ["KNN", "Logistic Regression", "Decision Tree", "Random Forest"]
precision = [precision_KNN, precision_logistic, precision_dt, precision_rf]
recall = [recall_KNN, recall_logistic, recall_dt, recall_rf]
f1 = [f1_KNN, f1_logistic, f1_dt, f1_rf]

plt.figure(figsize=(10, 6))
plt.bar(models, precision, width=0.4, label='Precision', align='center')
plt.bar(models, recall, width=0.4, label='Recall', align='edge')
plt.bar(models, f1, width=0.4, label='F1-score', align='edge')
plt.xlabel('Model')
plt.ylabel('Score')
plt.title('Performance Metrics for Different Models')
plt.legend()
plt.show()

# %%
from sklearn.metrics import recall_score

recall_KNN = recall_score(y_test, y_pred_KNN)
recall_logistic = recall_score(y_test, y_pred_logistic)
recall_dt = recall_score(y_test, y_pred_dt)
recall_rf = recall_score(y_test, y_pred_rf)

print("Recall for KNN:", recall_KNN)
print("Recall for Logistic Regression:", recall_logistic)
print("Recall for Decision Tree:", recall_dt)
print("Recall for Random Forest:", recall_rf)
# Out:
# Recall for KNN: 0.9812807881773399
# Recall for Logistic Regression: 0.9482758620689655
# Recall for Decision Tree: 0.9933497536945812
# Recall for Random Forest: 0.996551724137931

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# حساب مصفوفة الارتباط لكل نموذج
cm_KNN = confusion_matrix(y_test, y_pred_KNN)
cm_logistic = confusion_matrix(y_test, y_pred_logistic)
cm_dt = confusion_matrix(y_test, y_pred_dt)
cm_rf = confusion_matrix(y_test, y_pred_rf)

# إنشاء مصفوفة الارتباط لكل نموذج
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# رسم مصفوفة الارتباط لكل نموذج
sns.heatmap(cm_KNN, annot=True, cmap='Blues', fmt='g', ax=axes[0, 0])
axes[0, 0].set_title('Confusion Matrix - KNN')

sns.heatmap(cm_logistic, annot=True, cmap='Blues', fmt='g', ax=axes[0, 1])
axes[0, 1].set_title('Confusion Matrix - Logistic Regression')

sns.heatmap(cm_dt, annot=True, cmap='Blues', fmt='g', ax=axes[1, 0])
axes[1, 0].set_title('Confusion Matrix - Decision Tree')

sns.heatmap(cm_rf, annot=True, cmap='Blues', fmt='g', ax=axes[1, 1])
axes[1, 1].set_title('Confusion Matrix - Random Forest')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import recall_score
import seaborn as sns

# حساب معدل الاستدعاء لكل نموذج
recall_KNN = recall_score(y_test, y_pred_KNN)
recall_logistic = recall_score(y_test, y_pred_logistic)
recall_dt = recall_score(y_test, y_pred_dt)
recall_rf = recall_score(y_test, y_pred_rf)

# إنشاء DataFrame لمعدل الاستدعاء لكل نموذج
recall_data = {'Model': ['KNN', 'Logistic Regression', 'Decision Tree', 'Random Forest'],
              'Recall': [recall_KNN, recall_logistic, recall_dt, recall_rf]}
recall_df = pd.DataFrame(recall_data)

# رسم الرسم البياني
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Recall', data=recall_df, palette='Blues')
plt.title('Recall Score for Each Model')
plt.xlabel('Model')
plt.ylabel('Recall')
plt.xticks(rotation=45)
plt.ylim(0, 1)  # تعيين النطاق الرأسي للرسم البياني
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# قائمة بأسماء النماذج
models = ['KNN', 'Logistic Regression', 'Decision Tree', 'Random Forest']

# قائمة بمعدلات الاستدعاء لكل نموذج
recalls = [recall_KNN, recall_logistic, recall_dt, recall_rf]

# رسم الرسم البياني
plt.figure(figsize=(10, 6))
plt.bar(models, recalls, color='skyblue')
plt.title('Recall Score for Each Model')
plt.xlabel('Model')
plt.ylabel('Recall')
plt.ylim(0, 1)  # تعيين النطاق الرأسي للرسم البياني
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(models, recalls, marker='o', color='skyblue', label='Recall Score')
plt.title('Recall Score for Each Model')
plt.xlabel('Model')
plt.ylabel('Recall')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

# التنبؤ باستخدام النموذج
y_pred_train_cb = cb_model.predict(x_train)
y_pred_test_cb = cb_model.predict(x_test)

# حساب مقاييس الأداء
recall_cb_train = recall_score(y_train, y_pred_train_cb)
precision_cb_train = precision_score(y_train, y_pred_train_cb)
f1_cb_train = f1_score(y_train, y_pred_train_cb)

recall_cb_test = recall_score(y_test, y_pred_test_cb)
precision_cb_test = precision_score(y_test, y_pred_test_cb)
f1_cb_test = f1_score(y_test, y_pred_test_cb)

# طباعة نتائج مقاييس الأداء
print(f"Training Recall Score: {recall_cb_train}")
print(f"Training Precision Score: {precision_cb_train}")
print(f"Training F1 Score: {f1_cb_train}")

print(f"Test Recall Score: {recall_cb_test}")
print(f"Test Precision Score: {precision_cb_test}")
print(f"Test F1 Score: {f1_cb_test}")
# Out:
# Training Recall Score: 0.9991479390776441
# Training Precision Score: 0.9981911044903171
# Training F1 Score: 0.9986692925959441
# Test Recall Score: 0.9960591133004926
# Test Precision Score: 0.9958138389559222
# Test F1 Score: 0.9959364610269671

# %%
import matplotlib.pyplot as plt

# أسماء المقاييس
metrics = ['Recall', 'Precision', 'F1 Score']

# قيم مقاييس الأداء
train_scores = [recall_cb_train, precision_cb_train, f1_cb_train]
test_scores = [recall_cb_test, precision_cb_test, f1_cb_test]

# رسم الرسم البياني
plt.figure(figsize=(8, 5))

plt.plot(metrics, train_scores, marker='o', label='Training')
plt.plot(metrics, test_scores, marker='x', label='Test')

plt.title('Performance Metrics for CatBoostClassifier')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import joblib

# قائمة بجميع النماذج والبيانات ذات الصلة
models_data = {
    "KNN_model": KNN_model,
    "lg_model": lg_model,
    "dt_model": dt,
    "rf_model": rf,
    "ab_model": ab_model,
    "lgb_model": lgb_model,
    "cb_model": cb_model,
    "BNB_model": BNB_model,
    "v_clf": v_clf,
    "SVM_model": SVM_model,
    "x_train": x_train,
    "x_test": x_test,
    "y_train": y_train,
    "y_test": y_test
}

# حفظ النماذج والبيانات في ملف واحد
joblib.dump(models_data, 'models_data.pkl')
# Out:
# ['models_data.pkl']

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# المصادقة على حساب Google
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# تحميل الملفات إلى Google Drive
file_list = ['models_data.pkl']  # قم بتحديد قائمة بأسماء الملفات التي تريد رفعها
for file_name in file_list:
    file = drive.CreateFile({'title': file_name})
    file.SetContentFile(file_name)
    file.Upload()
    print(f"Uploaded {file_name} to Google Drive")
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Uploaded models_data.pkl to Google Drive

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file_name = 'models_data.pkl'  # اسم الملف الذي ترغب في تحميله
file_path = '/content/' + file_name  # المسار الذي يجب تحميل الملف إليه

# إنشاء ملف على Google Drive
uploaded_file = drive.CreateFile({'title': file_name})
uploaded_file.SetContentFile(file_path)
uploaded_file.Upload()

# %%
import joblib

# قم بتحميل المودلات من الملف pkl
models = joblib.load('models_data.pkl')

# قم بحفظ المودلات بصيغة joblib
joblib.dump(models, 'models_data.joblib')
# Out:
# ['models_data.joblib']

# %%
# !pip install github

# %%
from github import Github

# Enter your username and token here
username = "memegg"
token = "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"

# Specify the repository you want to upload the file to
repository_name = "inst-network"

# Name of the file you want to upload
file_name = "models_data.joblib"

# Open a session with GitHub using your credentials
g = Github(username, token)

# Get the repository
repo = g.get_user().get_repo(repository_name)

# Upload the file to the repository
with open(file_name, 'rb') as file:
    content = file.read()
    repo.create_file(file_name, "Add models_data.joblib", content)

print("File uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-74-338f058e5958> in <cell line: 1>()
# ----> 1 from github import Github
#       2
#       3 # Enter your username and token here
#       4 username = "memegg"
#       5 token = "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"
#
# ImportError: cannot import name 'Github' from 'github' (/usr/local/lib/python3.10/dist-packages/github/__init__.py)

# %%
import github
print(github.__version__)
# Out:
# 1.2.7

# %%
# !pip install --upgrade github

# %%
from github import Github
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-7c855228f3ce> in <cell line: 1>()
# ----> 1 from github import Github
#
# ImportError: cannot import name 'Github' from 'github' (/usr/local/lib/python3.10/dist-packages/github/__init__.py)

# %%
train=pd.read_csv('Train_data.csv')
test=pd.read_csv('Test_data.csv')
train
sns.countplot(x=train['class'])
def le(df):
    for col in df.columns:
        if df[col].dtype == 'object':
                label_encoder = LabelEncoder()
                df[col] = label_encoder.fit_transform(df[col])

le(train)
le(test)
train.drop(['num_outbound_cmds'], axis=1, inplace=True)
test.drop(['num_outbound_cmds'], axis=1, inplace=True)
train.head()
X_train = train.drop(['class'], axis=1)
Y_train = train['class']
rfc = RandomForestClassifier()

rfe = RFE(rfc, n_features_to_select=10)
rfe = rfe.fit(X_train, Y_train)

feature_map = [(i, v) for i, v in itertools.zip_longest(rfe.get_support(), X_train.columns)]
selected_features = [v for i, v in feature_map if i==True]

selected_features
X_train = X_train[selected_features]
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
test = scale.fit_transform(test)
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, train_size=0.70, random_state=2)
def objective(trial):
    n_neighbors = trial.suggest_int('KNN_n_neighbors', 2, 16, log=False)
    classifier_obj = KNeighborsClassifier(n_neighbors=n_neighbors)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy
study_KNN = optuna.create_study(direction='maximize')
study_KNN.optimize(objective, n_trials=1)
print(study_KNN.best_trial)
KNN_model = KNeighborsClassifier(n_neighbors=study_KNN.best_trial.params['KNN_n_neighbors'])
KNN_model.fit(x_train, y_train)

KNN_train, KNN_test = KNN_model.score(x_train, y_train), KNN_model.score(x_test, y_test)

print(f"Train Score: {KNN_train}")
print(f"Test Score: {KNN_test}")
lg_model = LogisticRegression(random_state = 42)
lg_model.fit(x_train, y_train)
lg_train, lg_test = lg_model.score(x_train , y_train), lg_model.score(x_test , y_test)

print(f"Training Score: {lg_train}")
print(f"Test Score: {lg_test}")
from sklearn.ensemble import RandomForestClassifier

def objective(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32, log=False)
    rf_max_features = trial.suggest_int('rf_max_features', 2, 10, log=False)
    classifier_obj = RandomForestClassifier(max_depth=rf_max_depth, max_features=rf_max_features)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy
    study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective, n_trials=30)
print(study_dt.best_trial)
# استيراد الطراز
from sklearn.tree import DecisionTreeClassifier

# التحقق من وجود المعلمات "dt_max_depth" و "dt_max_features"
if 'dt_max_depth' in study_dt.best_trial.params:
    dt_max_depth = study_dt.best_trial.params['dt_max_depth']
else:
    dt_max_depth = None

# إنشاء نموذج DecisionTreeClassifier باستخدام المعلمات
dt = DecisionTreeClassifier(max_depth=dt_max_depth)

# تدريب النموذج
dt.fit(x_train, y_train)

# حساب النتائج
dt_train_score = dt.score(x_train, y_train)
dt_test_score = dt.score(x_test, y_test)

print(f"Training Score: {dt_train_score}")
print(f"Test Score: {dt_test_score}")
fig = plt.figure(figsize = (30,12))
tree.plot_tree(dt, filled=True);
plt.show()
from matplotlib import pyplot as plt
def f_importance(coef, names, top=-1):
    imp = coef
    imp, names = zip(*sorted(list(zip(imp, names))))

    # Show all features
    if top == -1:
        top = len(names)

    plt.barh(range(top), imp[::-1][0:top], align='center')
    plt.yticks(range(top), names[::-1][0:top])
    plt.title('feature importance for dt')
    plt.show()

# whatever your features are called
features_names = selected_features

# Specify your top n features you want to visualize.
# You can also discard the abs() function
# if you are interested in negative contribution of features
f_importance(abs(dt.feature_importances_), features_names, top=7)
def objective(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32, log=False)
    rf_max_features = trial.suggest_int('rf_max_features', 2, 10, log=False)
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 3, 20, log=False)
    classifier_obj = RandomForestClassifier(max_features = rf_max_features, max_depth = rf_max_depth, n_estimators = rf_n_estimators)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy
    study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective, n_trials=30)
print(study_rf.best_trial)
rf = RandomForestClassifier(max_features = study_rf.best_trial.params['rf_max_features'], max_depth = study_rf.best_trial.params['rf_max_depth'], n_estimators = study_rf.best_trial.params['rf_n_estimators'])
rf.fit(x_train, y_train)

rf_train, rf_test = rf.score(x_train, y_train), rf.score(x_test, y_test)

print(f"Train Score: {rf_train}")
print(f"Test Score: {rf_test}")
from matplotlib import pyplot as plt

def f_importance(coef, names, top=-1):
    imp = coef
    imp, names = zip(*sorted(list(zip(imp, names))))

    # Show all features
    if top == -1:
        top = len(names)
    plt.barh(range(top), imp[::-1][0:top], align='center')
    plt.yticks(range(top), names[::-1][0:top])
    plt.title('feature importance for dt')
    plt.show()

# whatever your features are called
features_names = selected_features

# Specify your top n features you want to visualize.
# You can also discard the abs() function
# if you are interested in negative contribution of features
f_importance(abs(rf.feature_importances_), features_names, top=7)
lgb_model = LGBMClassifier(random_state=42)
lgb_model.fit(x_train, y_train)
lgb_train, lgb_test = lgb_model.score(x_train , y_train), lgb_model.score(x_test , y_test)

print(f"Training Score: {lgb_train}")
print(f"Test Score: {lgb_test}")
ab_model = AdaBoostClassifier(random_state=42)
ab_model.fit(x_train, y_train)
b_train, ab_test = ab_model.score(x_train , y_train), ab_model.score(x_test , y_test)

print(f"Training Score: {ab_train}")
print(f"Test Score: {ab_test}")
cb_model = CatBoostClassifier(verbose=0)
cb_model.fit(x_train, y_train)
cb_train, cb_test = cb_model.score(x_train , y_train), cb_model.score(x_test , y_test)

print(f"Training Score: {cb_train}")
print(f"Test Score: {cb_test}")
BNB_model = BernoulliNB()
BNB_model.fit(x_train, y_train)
BNB_train, BNB_test = BNB_model.score(x_train , y_train), BNB_model.score(x_test , y_test)

print(f"Training Score: {BNB_train}")
print(f"Test Score: {BNB_test}")
v_clf = VotingClassifier(estimators=[('KNeighborsClassifier', KNN_model), ("RandomForestClassifier", rf), ("DecisionTree", dt), ("LightGB", lgb_model), ("AdaBoost", ab_model), ("Catboost", cb_model)], voting = "hard")
v_clf.fit(x_train, y_train)
voting_train, voting_test = v_clf.score(x_train , y_train), v_clf.score(x_test , y_test)

print(f"Training Score: {voting_train}")
print(f"Test Score: {voting_test}")
def objective(trial):
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'linearSVC'])
    c = trial.suggest_float('c', 0.02, 1.0, step=0.02)
    if kernel in ['linear', 'rbf']:
        classifier_obj = SVC(kernel=kernel, C=c).fit(x_train, y_train)
    elif kernel == 'linearSVC':
        classifier_obj = LinearSVC(C=c).fit(x_train, y_train)
    elif kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 10)
        classifier_obj = SVC(kernel=kernel, C=c, degree=degree).fit(x_train, y_train)

    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy
    study_svm = optuna.create_study(direction='maximize')
study_svm.optimize(objective, n_trials=30)
print(study_svm.best_trial)
if study_svm.best_trial.params['kernel'] in ['linear', 'rbf']:
    SVM_model = SVC(kernel=study_svm.best_trial.params['kernel'], C=study_svm.best_trial.params['c'])
elif kernel == 'linearSVC':
    SVM_model = LinearSVC(C=study_svm.best_trial.params['c'])
elif kernel == 'poly':
    SVM_model = SVC(kernel=study_svm.best_trial.params['kernel'], C=study_svm.best_trial.params['c'], degree=study_svm.best_trial.params['degree'])

SVM_model.fit(x_train, y_train)
SVM_train, SVM_test = SVM_model.score(x_train , y_train), SVM_model.score(x_test , y_test)

print(f"Training Score: {SVM_train}")
print(f"Test Score: {SVM_test}")
# Train Decision Tree Classifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)

# Evaluate Decision Tree Classifier
dt_train = dt.score(x_train, y_train)
dt_test = dt.score(x_test, y_test)
data = [["KNN", KNN_train, KNN_test],
        ["Logistic Regression", lg_train, lg_test],
        ["Decision Tree", dt_train, dt_test],
        ["Random Forest", rf_train, rf_test],
        ["Adaboost", ab_train, ab_test],
        ["light GBM", lgb_train, lgb_test],
        ["CatBoost", cb_train, cb_test],
        ["Naive Baye Model", BNB_train, BNB_test],
        ["Voting", voting_train, voting_test],
        ["SVM", SVM_train, SVM_test]]

col_names = ["Model", "Train Score", "Test Score"]
print(tabulate(data, headers=col_names, tablefmt="fancy_grid"))
